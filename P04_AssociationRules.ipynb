# %% [markdown]
# <b>Aim/Objective: Market Basket Analysis using association rule mining using the Apriori algorithm.</b><br><br>
#
# <b>Concept/Theory of Experiments:</b>
# 1. Market Basket Analysis
# 2. Association rule mining using the apriori algorithm.
# 3. Interpretation of Support , Confidence and Lift values.

# %% [markdown]
# ### Importing the required libraries and dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df = pd.read_excel(r'C:\Users\maury\Desktop\College\SEM 4\DS401 (Machine Learning - II)\Practicals Skills\Practical4\Online Retail.xlsx')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# ### Basic Description of dataset

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %% [markdown]
# ### Checking for missing values

# %%
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# #### Observations:
# * We can see there are missing values present in Description and CustomerID column.

# %% [markdown]
# ### Analyse the most frequent items

# %%
df["Description"].value_counts().head(10)
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER    2369
# REGENCY CAKESTAND 3 TIER              2200
# JUMBO BAG RED RETROSPOT               2159
# PARTY BUNTING                         1727
# LUNCH BAG RED RETROSPOT               1638
# ASSORTED COLOUR BIRD ORNAMENT         1501
# SET OF 3 CAKE TINS PANTRY DESIGN      1473
# PACK OF 72 RETROSPOT CAKE CASES       1385
# LUNCH BAG  BLACK SKULL.               1350
# NATURAL SLATE HEART CHALKBOARD        1280
# Name: Description, dtype: int64

# %%
plt.figure(figsize=(9,6))
sns.countplot(df.Description, order=df["Description"].value_counts().head(10).index)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\maury\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### Observations:
# * WHITE HANGING HEART T-LIGHT HOLDER, REGENCY CAKESTAND 3 TIER, JUMBO BAG RED RETROSPOT are the 3 most frequent items in the dataset.

# %% [markdown]
# ### Analysing the country with most number of transaction

# %%
index = df["Country"].value_counts().head().index
index
# Out:
# Index(['United Kingdom', 'Germany', 'France', 'EIRE', 'Spain'], dtype='object')

# %%
plt.figure(figsize=(9,6))
sns.countplot(df.Country,order =index)
plt.ylim([0, 100000])
plt.show()
# Out:
# C:\Users\maury\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### Observations:
# * United Kingdom has the highest number of transactions.
# * Germany and France are followed by UK in the number of transactions.

# %% [markdown]
# ### Data Cleaning

# %%
#Removing spaces from descriptions
df['Description'] = df['Description'].str.strip()

#Dropping rows without invoice numbers
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)

#Removing credit transactions (those with invoice numbers containing C)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]

# %% [markdown]
# ### Market Basket Analysis For United Kingdom

# %%
basket = (df[df['Country'] =="United Kingdom"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
basket
# Out:
# Description  *Boombox Ipod Classic  *USB Office Mirror Ball  \
# InvoiceNo
# 536365                         0.0                      0.0
# 536366                         0.0                      0.0
# 536367                         0.0                      0.0
# 536368                         0.0                      0.0
# 536369                         0.0                      0.0
# ...                            ...                      ...
# 581585                         0.0                      0.0
# 581586                         0.0                      0.0
# A563185                        0.0                      0.0
# A563186                        0.0                      0.0
# A563187                        0.0                      0.0
#
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536365                          0.0                         0.0
# 536366                          0.0                         0.0
# ...

# %%
#One hot encoding of the data
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

sets = basket.applymap(encode_units)
sets.drop('POSTAGE', inplace=True, axis=1)

# %%
frequent_itemsets = apriori(sets, min_support=0.03, use_colnames=True)

# %%
rules = association_rules(frequent_itemsets, metric="lift")
rules
# Out:
#                             antecedents                          consequents  \
# 0            (ALARM CLOCK BAKELIKE RED)         (ALARM CLOCK BAKELIKE GREEN)
# 1          (ALARM CLOCK BAKELIKE GREEN)           (ALARM CLOCK BAKELIKE RED)
# 2     (GREEN REGENCY TEACUP AND SAUCER)     (PINK REGENCY TEACUP AND SAUCER)
# 3      (PINK REGENCY TEACUP AND SAUCER)    (GREEN REGENCY TEACUP AND SAUCER)
# 4     (ROSES REGENCY TEACUP AND SAUCER)    (GREEN REGENCY TEACUP AND SAUCER)
# 5     (GREEN REGENCY TEACUP AND SAUCER)    (ROSES REGENCY TEACUP AND SAUCER)
# 6             (JUMBO BAG RED RETROSPOT)     (JUMBO  BAG BAROQUE BLACK WHITE)
# 7      (JUMBO  BAG BAROQUE BLACK WHITE)            (JUMBO BAG RED RETROSPOT)
# 8             (JUMBO BAG RED RETROSPOT)            (JUMBO BAG PINK POLKADOT)
# 9             (JUMBO BAG PINK POLKADOT)            (JUMBO BAG RED RETROSPOT)
# 10            (JUMBO BAG RED RETROSPOT)  (JUMBO SHOPPER VINTAGE RED PAISLEY)
# ...

# %%
rules.sort_values('lift', ascending=False).head()
# Out:
#                          antecedents                        consequents  \
# 2  (GREEN REGENCY TEACUP AND SAUCER)   (PINK REGENCY TEACUP AND SAUCER)
# 3   (PINK REGENCY TEACUP AND SAUCER)  (GREEN REGENCY TEACUP AND SAUCER)
# 5  (GREEN REGENCY TEACUP AND SAUCER)  (ROSES REGENCY TEACUP AND SAUCER)
# 4  (ROSES REGENCY TEACUP AND SAUCER)  (GREEN REGENCY TEACUP AND SAUCER)
# 0         (ALARM CLOCK BAKELIKE RED)       (ALARM CLOCK BAKELIKE GREEN)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 2            0.050035            0.037660  0.030910    0.617773  16.403939
# 3            0.037660            0.050035  0.030910    0.820768  16.403939
# 5            0.050035            0.051267  0.037553    0.750535  14.639752
# 4            0.051267            0.050035  0.037553    0.732497  14.639752
# 0            0.049821            0.046928  0.030160    0.605376  12.900183
#
#    leverage  conviction
# 2  0.029026    2.517719
# 3  0.029026    5.300203
# ...

# %% [markdown]
# #### Observations:
# * We can see that GREEN REGENCY TEACUP AND SAUCER -> PINK REGENCY TEACUP AND SAUCER and vise versa has a very high lift, suggesting that both are bought together in most of the transactions.

# %% [markdown]
# ### Market Basket Analysis For Germany

# %%
basket = (df[df['Country'] =="Germany"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
basket
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536527                          0.0                         0.0
# 536840                          0.0                         0.0
# 536861                          0.0                         0.0
# 536967                          0.0                         0.0
# 536983                          0.0                         0.0
# ...                             ...                         ...
# 581266                          0.0                         0.0
# 581494                          0.0                         0.0
# 581570                          0.0                         0.0
# 581574                          0.0                         0.0
# 581578                          0.0                         0.0
#
# Description  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536527                                    0.0
# 536840                                    0.0
# ...

# %%
#One hot encoding of the data
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

sets = basket.applymap(encode_units)
sets.drop('POSTAGE', inplace=True, axis=1)

# %%
frequent_itemsets = apriori(sets, min_support=0.07, use_colnames=True)

# %%
rules = association_rules(frequent_itemsets, metric="lift")
rules
# Out:
#                             antecedents                           consequents  \
# 0    (PLASTERS IN TIN WOODLAND ANIMALS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 1  (ROUND SNACK BOXES SET OF4 WOODLAND)    (PLASTERS IN TIN WOODLAND ANIMALS)
# 2  (ROUND SNACK BOXES SET OF4 WOODLAND)   (ROUND SNACK BOXES SET OF 4 FRUITS)
# 3   (ROUND SNACK BOXES SET OF 4 FRUITS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 4  (ROUND SNACK BOXES SET OF4 WOODLAND)                  (SPACEBOY LUNCH BOX)
# 5                  (SPACEBOY LUNCH BOX)  (ROUND SNACK BOXES SET OF4 WOODLAND)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.137856            0.245077  0.074398    0.539683  2.202098
# 1            0.245077            0.137856  0.074398    0.303571  2.202098
# 2            0.245077            0.157549  0.131291    0.535714  3.400298
# 3            0.157549            0.245077  0.131291    0.833333  3.400298
# ...

# %%
rules.sort_values('lift', ascending=False).head()
# Out:
#                             antecedents                           consequents  \
# 3   (ROUND SNACK BOXES SET OF 4 FRUITS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 2  (ROUND SNACK BOXES SET OF4 WOODLAND)   (ROUND SNACK BOXES SET OF 4 FRUITS)
# 5                  (SPACEBOY LUNCH BOX)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 4  (ROUND SNACK BOXES SET OF4 WOODLAND)                  (SPACEBOY LUNCH BOX)
# 1  (ROUND SNACK BOXES SET OF4 WOODLAND)    (PLASTERS IN TIN WOODLAND ANIMALS)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 3            0.157549            0.245077  0.131291    0.833333  3.400298
# 2            0.245077            0.157549  0.131291    0.535714  3.400298
# 5            0.102845            0.245077  0.070022    0.680851  2.778116
# 4            0.245077            0.102845  0.070022    0.285714  2.778116
# 1            0.245077            0.137856  0.074398    0.303571  2.202098
#
#    leverage  conviction
# 3  0.092679    4.529540
# ...

# %% [markdown]
# #### Observations:
# * We can see that ROUND SNACK BOXES SET OF 4 FRUITS -> ROUND SNACK BOXES SET OF 4 FRUITS and vise versa has a high lift, suggesting that both are bought together in most of the transactions.

# %% [markdown]
# ### Market Basket Analysis For France

# %%
basket = (df[df['Country'] =="France"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
basket
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                          0.0                         0.0
# 536852                          0.0                         0.0
# 536974                          0.0                         0.0
# 537065                          0.0                         0.0
# 537463                          0.0                         0.0
# ...                             ...                         ...
# 580986                          0.0                         0.0
# 581001                          0.0                         0.0
# 581171                          0.0                         0.0
# 581279                          0.0                         0.0
# 581587                          0.0                         0.0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                             0.0                              0.0
# ...

# %%
#One hot encoding of the data
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

sets = basket.applymap(encode_units)
sets.drop('POSTAGE', inplace=True, axis=1)

# %%
frequent_itemsets = apriori(sets, min_support=0.07, use_colnames=True)

# %%
rules = association_rules(frequent_itemsets, metric="lift")
rules
# Out:
#                                           antecedents  \
# 0                         (ALARM CLOCK BAKELIKE PINK)
# 1                        (ALARM CLOCK BAKELIKE GREEN)
# 2                          (ALARM CLOCK BAKELIKE RED)
# 3                        (ALARM CLOCK BAKELIKE GREEN)
# 4                          (ALARM CLOCK BAKELIKE RED)
# 5                         (ALARM CLOCK BAKELIKE PINK)
# 6                                (SPACEBOY LUNCH BOX)
# 7                              (DOLLY GIRL LUNCH BOX)
# 8                     (PLASTERS IN TIN CIRCUS PARADE)
# 9                          (PLASTERS IN TIN SPACEBOY)
# 10                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 11                    (PLASTERS IN TIN CIRCUS PARADE)
# 12                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 13                         (PLASTERS IN TIN SPACEBOY)
# 14               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 15                      (SET/6 RED SPOTTY PAPER CUPS)
# ...

# %%
rules.sort_values('lift', ascending=False).head()
# Out:
#                         antecedents  \
# 2        (ALARM CLOCK BAKELIKE RED)
# 3      (ALARM CLOCK BAKELIKE GREEN)
# 4        (ALARM CLOCK BAKELIKE RED)
# 5       (ALARM CLOCK BAKELIKE PINK)
# 25  (SET/6 RED SPOTTY PAPER PLATES)
#
#                                           consequents  antecedent support  \
# 2                        (ALARM CLOCK BAKELIKE GREEN)            0.094388
# 3                          (ALARM CLOCK BAKELIKE RED)            0.096939
# 4                         (ALARM CLOCK BAKELIKE PINK)            0.094388
# 5                          (ALARM CLOCK BAKELIKE RED)            0.102041
# 25  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...            0.127551
#
#     consequent support   support  confidence      lift  leverage  conviction
# 2             0.096939  0.079082    0.837838  8.642959  0.069932    5.568878
# 3             0.094388  0.079082    0.815789  8.642959  0.069932    4.916181
# ...

# %% [markdown]
# #### Observations:
# * We can see that ALARM CLOCK BAKELIKE RED -> ALARM CLOCK BAKELIKE GREEN and vise versa has a high lift, suggesting that both are bought together in most of the transactions.

# %% [markdown]
# <b>Conclusion:</b>
# * The Apriori algorithm was applied to the “Online Retail” dataset to find the association between different items in online retail stores across different countries.
